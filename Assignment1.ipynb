# %%
#1. Student information

name = "Daniyal"
age = 17
city = "karachi"
s_status = "Student"

print(f"Name: {name}")
print(f"Age: {age}")
print(f"City: {city}")
print(f"Student's status: {s_status}")
# Out:
# Name: Daniyal
# Age: 17
# City: karachi
# Student's status: Student

# %%
#2. Data Types
name = "Daniyal"
age = 17
percentage = 78.6
s_status = True

print(name, type(name))
print(age, type(age))
print(percentage, type(percentage))
print(s_status, type(s_status))
# Out:
# Daniyal <class 'str'>
# 17 <class 'int'>
# 78.6 <class 'float'>
# True <class 'bool'>

# %%
#3.Arithmatic operations
num1 = 50
num2 = 5

print("Addition", num1+num2)
print("Subtraction", num1-num2)
print("Multiplication", num1*num2)
print("Division", num1/num2)
print("Modulus", num1%num2)
print("Power", num1**num2)
# Out:
# Addition 55
# Subtraction 45
# Multiplication 250
# Division 10.0
# Modulus 0
# Power 312500000

# %%
#4.Student marks calculator
english = 80
maths = 70
computer = 90

total_marks = english + maths + computer
average_marks = total_marks/3

print(f"Total marks: {total_marks}")
print(f"Average marks: {average_marks}")
# Out:
# Total marks: 240
# Average marks: 80.0

# %%
#5.Shopping bill
product = "Laptop"
price = 80000
quantity = 20

total_bill = price * quantity

print(f"Total bill: {total_bill}")
# Out:
# Total bill: 1600000

# %%
#6.Rectangle area
length = 12
width = 7

area = length * width
perimeter = 2 * (length + width)

print(f"Area: {area}")
print(f"Perimeter: {perimeter}")
# Out:
# Area: 84
# Perimeter: 38

# %%
#7.Time converter
total_minutes = 250

hours = total_minutes // 60
remaining_minutes = total_minutes % 60

print(f"Hours: {hours}")
print(f"Remaining minutes: {remaining_minutes}")
# Out:
# Hours: 4
# Remaining minutes: 10

# %%
#8.Student eligibility
name = "Daniyal"
marks = 80
attendence = 70

marks_eligibility_criteria = marks >= 50
attendence_eligibility_criteria = attendence >= 75

is_eligible = marks_eligibility_criteria and attendence_eligibility_criteria

print(f"Name: {name}")
print(f"Marks eligibility criteria: {marks_eligibility_criteria}")
print(f"Attendence eligibility criteria: {attendence_eligibility_criteria}")
print(f"Is student eligible: {is_eligible}")
# Out:
# Name: Daniyal
# Marks eligibility criteria: True
# Attendence eligibility criteria: False
# Is student eligible: False

# %%
#9.Logical operators
a = True
b = False

print(a and b)
print(a or b)
print(not a)
print(not b)
# Out:
# False
# True
# False
# True

# %%
#Final Challenge Student Report
name = "Daniyal"
age = 17
english_marks = 70
maths_marks = 80
computer_marks = 90
attendence = 76

total_marks = english_marks + maths_marks + computer_marks
average_marks = total_marks / 3
marks_eligibility_criteria = average_marks >= 50
attendence_eligibility_criteria = attendence >= 75
is_student_eligible = marks_eligibility_criteria and attendence_eligibility_criteria

print(f"Name: {name}")
print(f"Age: {age}")
print(f"English marks: {english_marks}")
print(f"Maths marks: {maths_marks}")
print(f"Computer marks: {computer_marks}")
print(f"Attendence: {attendence}")
print(f"Is student eligible: {is_student_eligible}")
# Out:
# Name: Daniyal
# Age: 17
# English marks: 70
# Maths marks: 80
# Computer marks: 90
# Attendence: 76
# Is student eligible: True
